# %% [markdown]
# <div dir="auto" align="center">
#     <h3>
#         بسم الله الرحمن الرحیم
#     </h3>
#     <br>
#     <h1>
#         <strong>
#             بازیابی پیشرفته اطلاعات
#         </strong>
#     </h1>
#     <h2>
#         <strong>
#             تمرین سوم (موتور جستجوی اخبار)
#         </strong>
#     </h2>
#     <br>
#     <h3>
#         محمد هجری - ٩٨١٠٦١٥٦
#         <br><br>
#         ارشان دلیلی - ٩٨١٠٥٧٥١
#         <br><br>
#         سروش جهان‌زاد - ٩٨١٠٠٣٨٩
#     </h3>
#     <br>
# </div>
# <hr>

# %% [markdown]
# <div>
#     <h3 style='direction:rtl;text-align:justify;'>
#         نصب و دسترسی به کتابخانه‌های مورد نیاز
#     </h3>
# </div>
#
# <div dir="auto" align="justify">
#     <p style='direction:rtl;text-align:justify;'>
#         با اجرای دو قطعه کد زیر، کتابخانه‌هایی که از آن‌ها در این تمرین استفاده شده است، نصب و قابل استفاده می‌شوند.
#     </p>
# </div>

# %%
# !pip install bs4
# !pip install tqdm
# !pip install pandas
# !pip install requests
# ! pip install fasttext

# %%
import os
import re
import csv
import zipfile
import requests
import fasttext
import numpy as np
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup

# %% [markdown]
# <div>
#     <h3 style='direction:rtl;text-align:justify;'>
#         ١. دریافت داده‌ها
#     </h3>
# </div>
#
# <div dir="auto" align="justify">
#     <p style='direction:rtl;text-align:justify;'>
#         در این تمرین، بیش از ٨٠ هزار خبر از
#         <a href="https://www.hamshahrionline.ir/"> وب‌سایت همشهری‌آنلاین </a>
#         گردآوری شده که در ١٠ دسته‌ی سیاسی، جهانی، اقتصادی، اجتماعی، شهری، ورزشی، علمی، فرهنگی، فناوری اطلاعات و مهارت‌های زندگی طبقه‌بندی شده‌اند.
#     </p>
# </div>

# %%
CATEGORIES = {
    'Politics': 'سیاسی',
    'World': 'جهانی',
    'Economy': 'اقتصادی',
    'Society': 'اجتماعی',
    'City': 'شهری',
    'Sport': 'ورزشی',
    'Science': 'علمی',
    'Culture': 'فرهنگی',
    'IT': 'فناوری اطلاعات',
    'LifeSkills': 'مهارت‌های زندگی',
}

# %% [markdown]
# <div dir="auto" align="justify">
#     <p style='direction:rtl;text-align:justify;'>
#         برای دریافت داده‌ها یک ماژول Scraper ساخته‌ایم که اخبار مربوط به ١٠ دسته‌ی مذکور را در بازه‌ی زمانی تعیین شده، کراول کرده و در فایل dataset.zip ذخیره و فشرده سازی می‌کند. کد مربوط به این ماژول را در زیر مشاهده می‌کنید.
#     </p>
# </div>

# %%
class Scraper:

    def __init__(self, current_year, current_month):
        self.current_year = current_year
        self.current_month = current_month

    def get_URL_content(self, URL):
        while True:
            try:
                return requests.get(URL, timeout=5).content
                break
            except:
                pass

    def generate_page_URL(self, page_index, category, year, month):
        tp = {'Politics': 6, 'World': 11, 'Economy': 10, 'Society': 5, 'City': 7,
              'Sport': 9, 'Science': 20, 'Culture': 26, 'IT': 718, 'LifeSkills': 21}[category]
        return f'https://www.hamshahrionline.ir/archive?pi={page_index}&tp={tp}&ty=1&ms=0&mn={month}&yr={year}'

    def get_page_URLs_by_time(self, category, year, month):
        URLs = []
        page_index = 1
        while True:
            URL = self.generate_page_URL(page_index, category, year, month)
            content = self.get_URL_content(URL)
            if re.findall('pagination', str(content)):
                URLs.append(URL)
                page_index += 1
            else:
                break
        return URLs

    def get_page_URLs_since(self, category, year, month):
        URLs = []
        with tqdm() as pbar:
            while True:
                if month > 12:
                    month = 1
                    year += 1
                pbar.set_description(f'[{category}] [Extracting page URLs] [Date: {year}/{month}]')
                URLs_by_time = self.get_page_URLs_by_time(category, year, month)
                if URLs_by_time:
                    for URL in URLs_by_time:
                        URLs.append(URL)
                    month += 1
                elif self.current_year > year or (self.current_year == year and self.current_month > month):
                    month += 1
                else:
                    break
        return URLs

    def get_news_URLs_since(self, category, year, month):
        news_URLs = []
        page_URLs = self.get_page_URLs_since(category, year, month)
        with tqdm(page_URLs) as pbar:
            for page_URL in pbar:
                content = self.get_URL_content(page_URL)
                soup = BeautifulSoup(content, 'html5lib')
                for item in soup.findAll('li', attrs={'class': 'news'}):
                    URL = item.find('div', attrs={'class': 'desc'}).find('h3').find('a')['href']
                    URL = 'https://www.hamshahrionline.ir' + URL
                    news_URLs.append(URL)
                pbar.set_description(f'[{category}] [Extracting news URLs] [{len(news_URLs)} news until now]')
        return news_URLs

    def parse_news(self, URL, category):
        try:
            content = self.get_URL_content(URL)
            soup = BeautifulSoup(content, 'html.parser')
            date = soup.find('div', {'class': 'col-6 col-sm-4 col-xl-4 item-date'}).span.text.strip()
            title = soup.find('div', {'class': 'item-title'}).h1.text.strip()
            intro = soup.find('p', {'class': 'introtext', 'itemprop': 'description'}).text.strip()
            body = soup.find('div', {'class': 'item-text', 'itemprop': 'articleBody'}).text.strip()
            category_PER = soup.find_all('li', {'class': 'breadcrumb-item'})
            category_PER = list(map(lambda x: x.text.strip(), category_PER))[1:]
            return {
                'date': date,
                'title': title,
                'intro': intro,
                'body': body,
                'category-PER': category_PER,
                'category-ENG': category,
            }
        except:
            return None

    def scrape(self, from_year, from_month):
        categories = ['Politics', 'World', 'Economy', 'Society', 'City',
                      'Sport', 'Science', 'Culture', 'IT', 'LifeSkills']
        news = []
        for category in categories:
            URLs = self.get_news_URLs_since(category, from_year, from_month)
            with tqdm(URLs) as pbar:
                pbar.set_description(f'[{category}] [Scraping news]')
                for URL in pbar:
                    news.append(self.parse_news(URL, category))
        news = list(filter(None, news))
        pd.DataFrame(news).to_csv(f'dataset.csv', encoding='utf-8')
        with zipfile.ZipFile('dataset.zip', 'w', zipfile.ZIP_DEFLATED) as zip_file:
            zip_file.write('dataset.csv')
        os.remove('dataset.csv')

# %% [markdown]
# <div dir="auto" align="justify">
#     <p style='direction:rtl;text-align:justify;'>
#         با اجرای قطعه کد زیر، یک instance از ماژول Scraper ایجاد شده و شروع به دریافت و ذخیره‌سازی داده‌ها می‌کند. خبرهای دریافت شده همگی مربوط به قرن جدید، از سال ١٤٠٠ به بعد هستند.
#     </p>
# </div>

# %%
scraper = Scraper(current_year=1401, current_month=3)
# scraper.scrape(from_year=1400, from_month=1)

# %% [markdown]
# <div dir="auto" align="justify">
#     <p style='direction:rtl;text-align:justify;'>
#         بعد از ذخیره شدن داده‌ها در فایل فشرده dataset.zip، آن‌ها را از این فایل استخراج کرده و وارد برنامه می‌کنیم. با اجرای قطعه کد زیر، تعداد خبرهای هر دسته و تعداد کل خبرها را می‌توان مشاهده کرد.
#     </p>
# </div>

# %%
def read_dataset_from_file():
    dataset = []
    with zipfile.ZipFile('dataset.zip', 'r') as zip_file:
        zip_file.extractall()
    with open('dataset.csv', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        header = next(csv_reader)
        for row in csv_reader:
            data = dict(zip(header[1:], row[1:]))
            dataset.append(data)
    return dataset


dataset = read_dataset_from_file()

# %% [markdown]
# <div dir="auto" align="justify">
#     <p style='direction:rtl;text-align:justify;'>
#     با اجرای قطعه کد زیر، تعداد خبرهای هر دسته و تعداد کل خبرها را می‌توان مشاهده کرد
#     </p>
# </div>

# %%
def display_dataset_info():
    global CATEGORIES

    length_dict = {key: 0 for key in CATEGORIES.keys()}
    for data in dataset:
        length_dict[data['category-ENG']] += 1

    df_dict = {
        'دسته': CATEGORIES.values(),
        'تعداد': length_dict.values(),
    }

    df = pd.DataFrame(df_dict)
    df.index += 1
    df.loc[0] = ['کل خبرها', len(dataset)]
    df = df.sort_index()
    display(df)


display_dataset_info()
# Out:
#                دسته  تعداد
# 0          کل خبرها  80986
# 1             سیاسی  15810
# 2             جهانی   4800
# 3           اقتصادی   9873
# 4           اجتماعی  14070
# 5              شهری   4260
# 6             ورزشی   8421
# 7              علمی   3267
# 8            فرهنگی   6657
# 9    فناوری اطلاعات    444
# 10  مهارت‌های زندگی  13384

# %%
dataset = pd.DataFrame(dataset)
dataset
# Out:
#                                   date  \
# 0      سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۳:۴۰
# 1      سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۳:۳۱
# 2      سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۳:۲۰
# 3      سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۲:۴۷
# 4      سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۲:۴۵
# ...                                ...
# 80981      یکشنبه ۱ خرداد ۱۴۰۱ - ۱۱:۵۴
# 80982      یکشنبه ۱ خرداد ۱۴۰۱ - ۱۱:۰۲
# 80983      یکشنبه ۱ خرداد ۱۴۰۱ - ۰۸:۰۰
# 80984      یکشنبه ۱ خرداد ۱۴۰۱ - ۰۷:۵۵
# 80985      یکشنبه ۱ خرداد ۱۴۰۱ - ۰۷:۲۰
#
#                                                    title  \
# 0               واشنگتن: آمریکا و ایران هدف مشترکی دارند
# 1      عراقچی باز هم ادعاهای «منبع مطلع» پرس‌تی‌وی در...
# 2      هشدار به دیپلمات‌های آمریکا در چاد؛ مراقب جان ...
# 3             نامه مشاور رهبری به نمکی درباره واکسن پولی
# 4           درخواست از روحانی: کشور را قرنطینه کامل کنید
# ...                                                  ...
# 80981     از زینک چه می‌دانید؟ | علائم کمبود زینک یا روی
# 80982  یک راهکار ساده برای مطمئن شدن از کیفیت عینک آف...
# 80983  تصاویری از سرزمین لک‌لک‌های ایران | زریوار میز...
# 80984  ۱۰ ترفند خانگی که سردردتان را بدون نیاز به قرص...
# 80985            معجزه آب و یک قاشق سرکه سیب برای سلامتی
#
#                                                    intro  \
# 0      سخنگوی وزارت خارجه آمریکا شامگاه سه‌شنبه در کن...
# 1      معاون وزیر امور خارجه جمهوری اسلامی ایران در ت...
# 2      وزارت خارجه آمریکا با صدور بیانیه‌ای به تمام د...
# 3      از درگیر کردن بخش خصوصی به شدت پرهیز شود، چه د...
# 4      حزب اتحاد ملت در نامه‌ای خطاب به روحانی خواستا...
# ...                                                  ...
# 80981  بدن شما نیاز به انواع مواد مغذی دارد تا عملکرد...
# 80982  استفاده از عینک آفتابی یک کار ضروری برای محافظ...
# 80983  بهار فصل خوبی برای سفر به کردستان است؛ جاده‌ها...
# 80984  سردرد مشکل نادری نیست و همه‌ ما گاهی دچارش می‌...
# 80985  احتمالاً شنیده‌اید که ترکیب آب و سرکه می‌تواند...
#
#                                                     body  \
# 0      به گزارش همشهری‌آنلاین به نقل از فارس، ند پرای...
# 1      به گزارش همشهری‌آنلاین به نقل از ایرنا، عباس ع...
# 2      به گزارش همشهری آنلاین به نقل از فارس، به دنبا...
# 3      به گزارش همشهری آنلاین به نقل از ایسنا، در نام...
# 4      به گزارش همشهری آنلاین به نقل از خبرآنلاین، مت...
# ...                                                  ...
# 80981  به گزارش همشهری آنلاین، بدن شما نیاز به انواع ...
# 80982  به گزارش همشهری آنلاین، بررسی‌ها نشان داده قرا...
# 80983  به گزارش همشهری آنلاین، شنیدن صدای لک‌لک‌ها یک...
# 80984  به گزارش همشهری آنلاین به نقل از سلامت نیوز، ت...
# 80985  به گزارش همشهری آنلاین به نقل از ایلنا، ‌ترکیب...
#
#                             category-PER category-ENG
# 0          ['سياست', 'سیاست\u200cخارجی']     Politics
# 1          ['سياست', 'سیاست\u200cخارجی']     Politics
# 2                     ['جهان', 'آمریکا']     Politics
# 3               ['سياست', 'سیاست داخلی']     Politics
# 4               ['سياست', 'سیاست داخلی']     Politics
# ...                                  ...          ...
# 80981               ['زندگی', 'تندرستی']   LifeSkills
# 80982  ['زندگی', 'مهارت\u200cهای زندگی']   LifeSkills
# 80983           ['زندگی', 'پیشنهاد سفر']   LifeSkills
# 80984               ['زندگی', 'تندرستی']   LifeSkills
# 80985               ['زندگی', 'تندرستی']   LifeSkills
#
# [80986 rows x 6 columns]

# %% [markdown]
# ## Fasttext

# %%
train_text = ''
train_text += ' '.join(list(dataset.loc[:, 'title']))
train_text += ' '.join(list(dataset.loc[:, 'intro']))
train_text += ' '.join(list(dataset.loc[:, 'body']))
with open('test.txt', 'w', encoding='utf-8') as fp:
    fp.write(train_text)

# %%
dataset.loc[:100,]
# Out:
#                                 date  \
# 0    سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۳:۴۰
# 1    سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۳:۳۱
# 2    سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۳:۲۰
# 3    سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۲:۴۷
# 4    سه‌شنبه ۳۱ فروردین ۱۴۰۰ - ۲۲:۴۵
# ..                               ...
# 96    یکشنبه ۲۹ فروردین ۱۴۰۰ - ۲۲:۱۹
# 97    یکشنبه ۲۹ فروردین ۱۴۰۰ - ۲۱:۵۴
# 98    یکشنبه ۲۹ فروردین ۱۴۰۰ - ۲۱:۳۰
# 99    یکشنبه ۲۹ فروردین ۱۴۰۰ - ۲۱:۱۰
# 100   یکشنبه ۲۹ فروردین ۱۴۰۰ - ۲۰:۲۸
#
#                                                  title  \
# 0             واشنگتن: آمریکا و ایران هدف مشترکی دارند
# 1    عراقچی باز هم ادعاهای «منبع مطلع» پرس‌تی‌وی در...
# 2    هشدار به دیپلمات‌های آمریکا در چاد؛ مراقب جان ...
# 3           نامه مشاور رهبری به نمکی درباره واکسن پولی
# 4         درخواست از روحانی: کشور را قرنطینه کامل کنید
# ..                                                 ...
# 96   عضو کارگزاران خطاب به فائزه هاشمی: تصور نکنید ...
# 97                     جانشین فرمانده نیروی قدس درگذشت
# 98   تصمیم جدید بورسی| اجرای اصلاح دستورالعمل رفع گ...
# 99                    داماد ترامپ؛ متهم کودتا در اردن!
# 100  دولت اپراتورهای اخلالگر در کلاب هاوس را نقره د...
#
#                                                  intro  \
# 0    سخنگوی وزارت خارجه آمریکا شامگاه سه‌شنبه در کن...
# 1    معاون وزیر امور خارجه جمهوری اسلامی ایران در ت...
# 2    وزارت خارجه آمریکا با صدور بیانیه‌ای به تمام د...
# 3    از درگیر کردن بخش خصوصی به شدت پرهیز شود، چه د...
# 4    حزب اتحاد ملت در نامه‌ای خطاب به روحانی خواستا...
# ..                                                 ...
# 96   یک عضو حزب کارگزاران سازندگی به‌تازگی در در وا...
# 97   روابط عمومی کل سپاه پاسداران انقلاب اسلامی در ...
# 98   هیات مدیره سازمان بورس اعلام کرد: اجرای مصوبه ...
# 99   رئیس مجلس اعیان اردن با اشاره به دخالت طرف‌های...
# 100  معاون ارتباطات و اطلاع رسانی دفتر رییس‌جمهور ا...
#
#                                                   body  \
# 0    به گزارش همشهری‌آنلاین به نقل از فارس، ند پرای...
# 1    به گزارش همشهری‌آنلاین به نقل از ایرنا، عباس ع...
# 2    به گزارش همشهری آنلاین به نقل از فارس، به دنبا...
# 3    به گزارش همشهری آنلاین به نقل از ایسنا، در نام...
# 4    به گزارش همشهری آنلاین به نقل از خبرآنلاین، مت...
# ..                                                 ...
# 96   به گزارش همشهری آنلاین به نقل از خبرآنلاین، چن...
# 97   به گزارش همشهری‌آنلاین به نقل از ایسنا، متن اط...
# 98   به گزارش همشهری آنلاین به نقل از بازار سرمایه ...
# 99   به گزارش همشهری آنلاین به نقل از فارس، رئیس مج...
# 100  به گزارش همشهری‌آنلاین، علیرضا معزی، معاون ارت...
#
#                       category-PER category-ENG
# 0    ['سياست', 'سیاست\u200cخارجی']     Politics
# 1    ['سياست', 'سیاست\u200cخارجی']     Politics
# 2               ['جهان', 'آمریکا']     Politics
# 3         ['سياست', 'سیاست داخلی']     Politics
# 4         ['سياست', 'سیاست داخلی']     Politics
# ..                             ...          ...
# 96        ['سياست', 'سیاست داخلی']     Politics
# 97         ['سياست', 'دفاع-امنیت']     Politics
# 98              ['اقتصاد', 'بورس']     Politics
# 99            ['جهان', 'غرب آسیا']     Politics
# 100              ['سياست', 'دولت']     Politics
#
# [101 rows x 6 columns]

# %%
class FastText:
    
    def __init__(self, method="skipgram", k=5):
        self.model = None
        self.method = method
        self.k = k
    
    def train(self, dataset):
        # train_text = ''
        # train_text += ' '.join(list(dataset.loc[:100, 'title']))
        # train_text += ' '.join(list(dataset.loc[:100, 'intro']))
        # train_text += ' '.join(list(dataset.loc[:100, 'body']))
        
        self.model = fasttext.train_unsupervised('test.txt', self.method, minn=2, maxn=5)

    def predict(self, query, dataset):
        query_embed = np.mean([self.model.get_word_vector(x) for x in query], axis=0)
        dataset_sim = []
        for index, row in dataset.iterrows():
            title_embed = [self.model.get_word_vector(x) for x in row['title']]
            intro_embed = [self.model.get_word_vector(x) for x in row['intro']]
            body_embed = [self.model.get_word_vector(x) for x in row['body']]
            row_embed = np.mean(title_embed + intro_embed + body_embed, axis=0)
            row_cosine_sim = self.cosine_sim(query_embed, row_embed)
            dataset_sim.append(row_cosine_sim)
        idx = np.argsort(dataset_sim)
        return dataset.iloc[list(idx[:self.k])]

    def cosine_sim(self, query, row):
        return np.dot(query, row) / (np.linalg.norm(query) * np.linalg.norm(row))

    def save_ft_model(self, path="fasttext_model.bin"):
        self.model.save_model(path)
    
    def load_ft_model(self, path="fasttext_model.bin"):
        self.model = fasttext.load_model(path)

# %%
ft = FastText()
ft.train(dataset)
ft.save_ft_model()
ft.load_ft_model()
# Out:
# Read 37M words
# Number of words:  114861
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   44850 lr:  0.000000 avg.loss:  1.211225 ETA:   0h 0m 0s  0.6% words/sec/thread:   49873 lr:  0.049703 avg.loss:  1.771887 ETA:   0h 5m42s  2.5% words/sec/thread:   50840 lr:  0.048757 avg.loss:  1.687997 ETA:   0h 5m29s  5.2% words/sec/thread:   49799 lr:  0.047377 avg.loss:  1.718990 ETA:   0h 5m26s  5.7% words/sec/thread:   47999 lr:  0.047146 avg.loss:  1.729022 ETA:   0h 5m37s  9.0% words/sec/thread:   49969 lr:  0.045477 avg.loss:  1.751786 ETA:   0h 5m12s  9.2% words/sec/thread:   49999 lr:  0.045414 avg.loss:  1.751672 ETA:   0h 5m12s 10.0% words/sec/thread:   48708 lr:  0.045014 avg.loss:  1.757065 ETA:   0h 5m17s 10.3% words/sec/thread:   48707 lr:  0.044855 avg.loss:  1.757408 ETA:   0h 5m16s 10.8% words/sec/thread:   48309 lr:  0.044582 avg.loss:  1.754991 ETA:   0h 5m17s 12.4% words/sec/thread:   47559 lr:  0.043787 avg.loss:  1.742075 ETA:   0h 5m16s 16.2% words/sec/thread:   46568 lr:  0.041913 avg.loss:  1.747172 ETA:   0h 5m 9s 18.2% words/sec/thread:   46720 lr:  0.040911 avg.loss:  1.743403 ETA:   0h 5m 0s 19.7% words/sec/thread:   46182 lr:  0.040151 avg.loss:  1.749176 ETA:   0h 4m58s 19.9% words/sec/thread:   46051 lr:  0.040057 avg.loss:  1.749713 ETA:   0h 4m58s 20.2% words/sec/thread:   45952 lr:  0.039888 avg.loss:  1.751009 ETA:   0h 4m58s 23.1% words/sec/thread:   45956 lr:  0.038429 avg.loss:  1.754715 ETA:   0h 4m47s 23.2% words/sec/thread:   45924 lr:  0.038410 avg.loss:  1.754590 ETA:   0h 4m47s 24.2% words/sec/thread:   45847 lr:  0.037885 avg.loss:  1.755085 ETA:   0h 4m43s 24.4% words/sec/thread:   45860 lr:  0.037801 avg.loss:  1.755333 ETA:   0h 4m43s 24.8% words/sec/thread:   45846 lr:  0.037586 avg.loss:  1.755419 ETA:   0h 4m41s 31.7% words/sec/thread:   45889 lr:  0.034160 avg.loss:  1.759228 ETA:   0h 4m15s 31.7% words/sec/thread:   45881 lr:  0.034136 avg.loss:  1.759270 ETA:   0h 4m15s 35.3% words/sec/thread:   45962 lr:  0.032346 avg.loss:  1.735019 ETA:   0h 4m 1s 35.5% words/sec/thread:   45988 lr:  0.032226 avg.loss:  1.732810 ETA:   0h 4m 0s 35.6% words/sec/thread:   45989 lr:  0.032199 avg.loss:  1.732536 ETA:   0h 4m 0s 37.5% words/sec/thread:   45964 lr:  0.031226 avg.loss:  1.718645 ETA:   0h 3m53s 39.9% words/sec/thread:   45704 lr:  0.030055 avg.loss:  1.701517 ETA:   0h 3m45s 40.3% words/sec/thread:   45662 lr:  0.029869 avg.loss:  1.699120 ETA:   0h 3m44s 40.5% words/sec/thread:   45689 lr:  0.029736 avg.loss:  1.697548 ETA:   0h 3m43s 41.0% words/sec/thread:   45738 lr:  0.029508 avg.loss:  1.694955 ETA:   0h 3m41s 48.2% words/sec/thread:   45169 lr:  0.025887 avg.loss:  1.652643 ETA:   0h 3m16s 49.4% words/sec/thread:   45250 lr:  0.025294 avg.loss:  1.647497 ETA:   0h 3m12s 50.4% words/sec/thread:   45332 lr:  0.024805 avg.loss:  1.643085 ETA:   0h 3m 8s 54.8% words/sec/thread:   45536 lr:  0.022585 avg.loss:  1.629246 ETA:   0h 2m50s 55.0% words/sec/thread:   45554 lr:  0.022479 avg.loss:  1.628839 ETA:   0h 2m49s 55.3% words/sec/thread:   45571 lr:  0.022374 avg.loss:  1.628170 ETA:   0h 2m48s 60.7% words/sec/thread:   45277 lr:  0.019643 avg.loss:  1.613577 ETA:   0h 2m29s 63.1% words/sec/thread:   45356 lr:  0.018472 avg.loss:  1.608321 ETA:   0h 2m19s 64.0% words/sec/thread:   45228 lr:  0.018024 avg.loss:  1.606666 ETA:   0h 2m16s 65.3% words/sec/thread:   45044 lr:  0.017366 avg.loss:  1.602936 ETA:   0h 2m12s 67.3% words/sec/thread:   44832 lr:  0.016325 avg.loss:  1.599468 ETA:   0h 2m 5s 68.6% words/sec/thread:   44733 lr:  0.015694 avg.loss:  1.597139 ETA:   0h 2m 0s 71.2% words/sec/thread:   44477 lr:  0.014423 avg.loss:  1.593634 ETA:   0h 1m51s 71.5% words/sec/thread:   44468 lr:  0.014258 avg.loss:  1.589582 ETA:   0h 1m50s 71.8% words/sec/thread:   44451 lr:  0.014115 avg.loss:  1.584888 ETA:   0h 1m49s 78.4% words/sec/thread:   44110 lr:  0.010789 avg.loss:  1.474267 ETA:   0h 1m24s 82.7% words/sec/thread:   44168 lr:  0.008671 avg.loss:  1.409579 ETA:   0h 1m 7s 85.7% words/sec/thread:   44261 lr:  0.007147 avg.los ...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
res = ft.predict(['بسکتبال', 'توپ'], dataset.loc[50000:52000])
res
# Out:
#                                  date  \
# 51505    دوشنبه ۱۱ مرداد ۱۴۰۰ - ۱۴:۳۱
# 50049   سه‌شنبه ۲۵ خرداد ۱۴۰۰ - ۲۰:۱۵
# 51949  پنجشنبه ۲۵ شهریور ۱۴۰۰ - ۱۸:۰۵
# 50950     چهارشنبه ۹ تیر ۱۴۰۰ - ۱۸:۳۰
# 50489     پنجشنبه ۳۱ تیر ۱۴۰۰ - ۲۱:۱۴
#
#                                                    title  \
# 51505    تصاویر | اشک‌های گرایی پس از شکست در نیمه نهایی
# 50049  هشدار بازیکنان عراق به هواداران در خصوص بازی ب...
# 51949  عکس | وحید امیری کنار ستاره سرشناس جهان روی صف...
# 50950             داور زن ایرانی جام جهانی را از دست داد
# 50489  عکس | انتقاد علی دایی از شرایط ایجاد شده در خو...
#
#                                                    intro  \
# 51505  سعید گرایی که با یک فن جذاب از سد حریف کروات گ...
# 50049  بازیکنان تیم ملی عراق در فضای مجازی به هوادارا...
# 51949  صفحه رسمی جام جهانی مقایسه‌ای میان ستاره تیم م...
# 50950  داور زن ایرانی یکی از نامزدهای قضاوت در جام فو...
# 50489         علی دایی نسبت به وضعیت خوزستان انتقاد کرد.
#
#                                                     body  \
# 51505  رقابت گرایی با حریف مجارستانی\n\n\n\nرقابت گرا...
# 50049  به گزارش همشهری آنلاین ایران در حالی باید تا س...
# 51949  به گزارش همشهری‌آنلاین، صفحه رسمی جام جهانی فی...
# 50950  به گزارش همشهری آنلاین فتحی که در مسابقات انتخ...
# 50489  به گزارش همشهری آنلاین علی دایی کاپیتان سابق ت...
#
#                               category-PER category-ENG
# 51505  ['ورزش', 'کشتی و وزنه\u200cبرداری']        Sport
# 50049             ['ورزش', 'فوتبال ايران']        Sport
# 51949             ['ورزش', 'فوتبال ايران']        Sport
# 50950              ['ورزش', 'فوتبال جهان']        Sport
# 50489             ['ورزش', 'فوتبال ايران']        Sport
